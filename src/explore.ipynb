# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# Cargar el conjunto de datos Iris
iris = load_iris()
X, y = iris.data, iris.target

# Crear y entrenar el modelo de árbol de decisión
clf = DecisionTreeClassifier()
clf.fit(X, y)

# Realizar una predicción sobre el primer ejemplo
prediccion = clf.predict([X[0]])
print("Predicción para el primer ejemplo:", prediccion)

#guarda el modelo entrenado en la carpeta ../models
from pickle import dump
with open('../models/decision_tree_model.pkl', 'wb') as f:
    dump(clf, f)

# %% [markdown]
# CONCLUSIONES:
#
# - Es importante conocer HTML y CSS para construir aplicaciones con mejor visualización e interfaz más amigable a los usuarios
# - Fue difícil configurar el codespace pero una vez terminado, es una aplicación fácil de usar. Permite entregar una interfaz para que un usuario pueda interactuar y usar modelos que previamente han sido entrenados.
